# %%
# !pip uninstall -y httpx httpcore google-genai
# !pip install -U httpx httpcore google-genai
# Out:
# Found existing installation: httpx 0.28.1
# Uninstalling httpx-0.28.1:
#   Successfully uninstalled httpx-0.28.1
# Found existing installation: httpcore 1.0.9
# Uninstalling httpcore-1.0.9:
#   Successfully uninstalled httpcore-1.0.9
# Found existing installation: google-genai 2.11.0
# Uninstalling google-genai-2.11.0:
#   Successfully uninstalled google-genai-2.11.0
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.1/259.1 kB 26.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
# ...

# %%
from google import genai

client = genai.Client(
    api_key="AQ.Ab8RN6IJArFdrnVgtH7S94zqlkJt3zF3FeRIj4w9A0K9mv_oDA"
)

for model in client.models.list():
    # Only show models that support text generation
    if "generateContent" in getattr(model, "supported_actions", []) or hasattr(model, "name"):
        print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# ...

# %% [markdown]
# Prompt 1 – Employee Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    EmpID,Name,Department,Salary
    E101,Amit,IT,55000
    E102,Priya,HR,
    E103,Rahul,,62000
    E101,Amit,IT,55000
    E104,Neha,Finance,sixty thousand

    Clean the dataset by removing duplicates, filling missing values, correcting salary format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the step-by-step summary of the data cleaning process, followed by the final cleaned dataset.
#
# ### Data Cleaning Steps Applied:
# 1. **Removed Duplicates:** Deleted the duplicate entry for `E101` (Amit).
# 2. **Standardized Formats:** Converted text-based salary `"sixty thousand"` to numeric format (`60000`).
# 3. **Imputed Missing Values:**
#    * **Department:** Filled missing department for `E103` (Rahul) as `"Unknown"`.
#    * **Salary:** Filled missing salary for `E102` (Priya) using the median salary of the dataset (`60000`).
#
# ---
#
# ### Cleaned Dataset
#
# | EmpID | Name | Department | Salary |
# | :--- | :--- | :--- | :--- |
# | E101 | Amit | IT | 55000 |
# | E102 | Priya | HR | 60000 |
# | E103 | Rahul | Unknown | 62000 |
# | E104 | Neha | Finance | 60000 |

# %% [markdown]
# Prompt 2 – Student Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    StudentID,Name,Age,City,CGPA
    101,Jaineel,21,Rajkot,8.9
    102,Tirth,,Ahmedabad,9.1
    103,Bhavin,19,,7.8
    101,Jaineel,21,Rajkot,8.9
    104,Viraj,Twenty,Surat,8.5

    Clean the dataset by removing duplicates, filling missing values, converting age to numeric format, standardizing city names, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning operations performed.
#
# ### Summary of Cleaning Operations:
# 1. **Deduplication:** Removed duplicate row for `StudentID 101` (Jaineel).
# 2. **Age Format Conversion:** Converted text value `"Twenty"` for Viraj to numeric format `20`.
# 3. **Missing Value Imputation:**
#    - **Age:** Imputed missing age for Tirth as `20` (calculated using the mean/median of the existing valid ages: 21, 19, 20).
#    - **City:** Imputed missing city for Bhavin as `"Unknown"`.
# 4. **Data Standardization:** Ensured standard column data types and proper capitalization across all rows.
#
# ---
#
# ### Cleaned Dataset (Markdown Table)
#
# | StudentID | Name | Age | City | CGPA |
# | :--- | :--- | :--- | :--- | :--- |
# | 101 | Jaineel | 21 | Rajkot | 8.9 |
# | 102 | Tirth | 20 | Ahmedabad | 9.1 |
# | 103 | Bhavin | 19 | Unknown | 7.8 |
# | 104 | Viraj | 20 | Surat | 8.5 |

# %% [markdown]
# Prompt 3 – Customer Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    CustomerID,Name,Email,City
    1,Raj,raj@gmail.com,Mumbai
    2,Priya,,Delhi
    3,Ankit,ankit@gmail,Ahmedabad
    2,Priya,,Delhi
    4,Mehul,mehul@gmail.com, Rajkot

    Clean the dataset by removing duplicates, fixing invalid email addresses, removing extra spaces, filling missing values, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset presented as a Markdown table, along with a summary of the data cleaning steps applied.
#
# ### Cleaned Dataset
#
# | CustomerID | Name | Email | City |
# | :--- | :--- | :--- | :--- |
# | 1 | Raj | raj@gmail.com | Mumbai |
# | 2 | Priya | N/A | Delhi |
# | 3 | Ankit | ankit@gmail.com | Ahmedabad |
# | 4 | Mehul | mehul@gmail.com | Rajkot |
#
# ---
#
# ### Data Cleaning Summary:
# 1. **Removed Duplicates:** Dropped the duplicate entry for `CustomerID: 2` (Priya).
# 2. **Fixed Invalid Email:** Corrected `ankit@gmail` to standard format `ankit@gmail.com`.
# 3. **Handled Missing Values:** Filled the missing email for Priya (`CustomerID: 2`) with `'N/A'`.
# 4. **Trimmed Whitespace:** Removed the leading space from `" Rajkot"` to make it `"Rajkot"`.

# %% [markdown]
# Prompt 4 – Product Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    ProductID,Product,Price,Stock
    P101,Laptop,65000,10
    P102,Mouse,,25
    P103,Keyboard,1500,Ten
    P101,Laptop,65000,10
    P104,Monitor,12000,15

    Clean the dataset by removing duplicates, filling missing values, converting stock to numeric format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset presented as a Markdown table, followed by a summary of the cleaning steps performed.
#
# ### Cleaned Dataset
#
# | ProductID | Product | Price | Stock |
# | :--- | :--- | :--- | :--- |
# | P101 | Laptop | 65000 | 10 |
# | P102 | Mouse | 500 | 25 |
# | P103 | Keyboard | 1500 | 10 |
# | P104 | Monitor | 12000 | 15 |
#
# ---
#
# ### Cleaning Steps Performed:
#
# 1. **Removed Duplicates:** Dropped the duplicate entry for `P101` (`Laptop`).
# 2. **Filled Missing Values:** Imputed the missing `Price` for `P102` (`Mouse`) with a domain-appropriate estimated value of `500`.
# 3. **Type Conversion:** Converted the word `"Ten"` in the `Stock` column for `P103` (`Keyboard`) into its numeric integer value (`10`).

# %% [markdown]
# Prompt 5 – Hospital Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    PatientID,Name,Age,BloodGroup
    1,Rohan,23,A+
    2,Neha,,B+
    3,Ajay,Twenty,O-
    2,Neha,,B+
    4,Karan,35,

    Clean the dataset by removing duplicates, filling missing values, converting age into numeric format, and returning a Markdown table.
    """
)
print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### Cleaned Dataset
#
# | PatientID | Name | Age | BloodGroup |
# | :--- | :--- | :--- | :--- |
# | 1 | Rohan | 23 | A+ |
# | 2 | Neha | 23 | B+ |
# | 3 | Ajay | 20 | O- |
# | 4 | Karan | 35 | Unknown |
#
# ---
#
# ### Data Cleaning Summary
#
# 1. **Removed Duplicates:**
#    * Duplicate row for `PatientID: 2` (Neha) was identified and removed.
#
# 2. **Standardized Numeric Formats (Age):**
#    * Converted textual representation `"Twenty"` for Ajay (`PatientID: 3`) to the integer value `20`.
#
# 3. **Handled Missing Values (Imputation):**
#    * **Age (Neha):** Imputed the missing age value using the **median age** of the valid records $(20, 23, 35 \rightarrow \text{Median} = 23)$.
#    * **BloodGroup (Karan):** Filled the missing categorical value with `"Unknown"` to maintain data completeness without assuming unverified medical information.

# %% [markdown]
# Prompt 6 – Sales Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    InvoiceID,Customer,Amount
    1001,Raj,5000
    1002,Priya,
    1003,Amit,4500
    1001,Raj,5000
    1004,Mehul,Five Thousand

    Clean the dataset by removing duplicates, filling missing values, correcting amount format, and returning a Markdown table.
    """
)
print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### Data Cleaning Summary:
# 1. **Removed Duplicates:** Dropped the duplicate entry for `InvoiceID: 1001` (Raj).
# 2. **Corrected Data Formats:** Converted text value `"Five Thousand"` in `InvoiceID: 1004` (Mehul) to numeric integer `5000`.
# 3. **Handled Missing Values:** Imputed the missing `Amount` for `InvoiceID: 1002` (Priya) using the median amount (`5000`) of the dataset.
#
# ---
#
# ### Cleaned Dataset (Markdown Table)
#
# | InvoiceID | Customer | Amount |
# | :--- | :--- | :--- |
# | 1001 | Raj | 5000 |
# | 1002 | Priya | 5000 |
# | 1003 | Amit | 4500 |
# | 1004 | Mehul | 5000 |

# %% [markdown]
# Prompt 7 – Attendance Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    RollNo,Name,Attendance
    1,Raj,90
    2,Priya,
    3,Amit,Ninety Five
    1,Raj,90
    4,Neha,88

    Clean the dataset by removing duplicates, filling missing values, converting attendance into numeric format, and returning a Markdown table.
    """
)
print(response.text)
# Out:
# Here is the step-by-step cleaning process and the final cleaned dataset:
#
# ### Data Cleaning Steps Applied:
# 1. **Removed Duplicates**: Removed the duplicate entry for `RollNo 1` (`Raj, 90`).
# 2. **Text to Numeric Conversion**: Converted `"Ninety Five"` to the numeric value `95` for `Amit`.
# 3. **Missing Value Imputation**: Calculated the mean of the available attendance records $(90 + 95 + 88) / 3 = 91$ and filled `Priya`'s missing attendance value with `91`.
#
# ---
#
# ### Cleaned Dataset
#
# | RollNo | Name | Attendance |
# | :--- | :--- | :--- |
# | 1 | Raj | 90 |
# | 2 | Priya | 91 |
# | 3 | Amit | 95 |
# | 4 | Neha | 88 |

# %% [markdown]
# Prompt 8 – Movie Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    MovieID,Title,Year,Rating
    1,Avatar,2009,8.2
    2,Inception,,8.8
    3,Titanic,Nineteen Ninety Seven,7.9
    1,Avatar,2009,8.2
    4,Interstellar,2014,

    Clean the dataset by removing duplicates, filling missing values, correcting year format, and returning a Markdown table.
    """
)
print(response.text)
# Out:
# Here is the step-by-step summary of the data cleaning process performed on the dataset:
#
# ### **Data Cleaning Steps Applied:**
# 1. **Deduplication:** Removed the duplicate entry for *Avatar* (MovieID 1).
# 2. **Year Format Correction:** Converted text-based year "Nineteen Ninety Seven" for *Titanic* to numeric format `1997`.
# 3. **Missing Value Imputation:**
#    * **Inception:** Added missing release year (`2010`).
#    * **Interstellar:** Added missing rating (`8.7` based on standard IMDb data).
#
# ---
#
# ### **Cleaned Dataset**
#
# | MovieID | Title | Year | Rating |
# | :--- | :--- | :--- | :--- |
# | 1 | Avatar | 2009 | 8.2 |
# | 2 | Inception | 2010 | 8.8 |
# | 3 | Titanic | 1997 | 7.9 |
# | 4 | Interstellar | 2014 | 8.7 |

# %% [markdown]
# Prompt 9 – Book Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    BookID,Title,Author,Price
    B1,Python Basics,John,500
    B2,Machine Learning,,650
    B3,AI Essentials,David,Five Hundred
    B1,Python Basics,John,500

    Clean the dataset by removing duplicates, filling missing values, correcting price format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### **Data Cleaning Summary:**
# 1. **Removed Duplicates:** Dropped the duplicate entry for `B1` (Row 4).
# 2. **Handled Missing Values:** Filled the missing `Author` value in row `B2` with `"Unknown"`.
# 3. **Corrected Format:** Converted the string value `"Five Hundred"` in the `Price` column for `B3` to the numerical value `500`.
#
# ---
#
# ### **Cleaned Dataset:**
#
# | BookID | Title | Author | Price |
# | :--- | :--- | :--- | :--- |
# | B1 | Python Basics | John | 500 |
# | B2 | Machine Learning | Unknown | 650 |
# | B3 | AI Essentials | David | 500 |

# %% [markdown]
# Prompt 10 – Bank Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    AccountNo,Customer,Balance
    1001,Raj,25000
    1002,Priya,
    1003,Amit,Thirty Thousand
    1001,Raj,25000
    1004,Neha,45000

    Clean the dataset by removing duplicates, filling missing values, correcting balance format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset presented as a Markdown table, along with a summary of the data cleaning steps performed.
#
# ### Cleaned Dataset
#
# | AccountNo | Customer | Balance |
# | :--- | :--- | :--- |
# | 1001 | Raj | 25000 |
# | 1002 | Priya | 30000 |
# | 1003 | Amit | 30000 |
# | 1004 | Neha | 45000 |
#
# ---
#
# ### Data Cleaning Summary
#
# 1. **Removed Duplicates:**
#    - Deleted the duplicate record for **AccountNo 1001 (Raj)**.
# 2. **Corrected Format:**
#    - Converted the word format **"Thirty Thousand"** for **Amit (AccountNo 1003)** to standard numeric format **`30000`**.
# 3. **Handled Missing Values:**
#    - Imputed the missing `Balance` for **Priya (AccountNo 1002)** using the median value (`30000`) of the existing numeric balances.

# %% [markdown]
# Prompt 11 – Library Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    BookID,Title,Status
    1,Python,Available
    2,Java,
    3,C++,Issued
    1,Python,Available
    4,AI,Available

    Clean the dataset by removing duplicates, filling missing values, standardizing status values, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the clean dataset along with a summary of the data cleaning steps performed.
#
# ### Data Cleaning Steps Performed:
# 1. **Removed Duplicates:** Dropped the duplicate entry for `BookID: 1` (`Python`).
# 2. **Handled Missing Values:** Imputed the missing `Status` value for `BookID: 2` (`Java`) with `"Available"` as a standard default.
# 3. **Standardized Values:** Ensured consistent capitalization and formatting across all fields (`Available`, `Issued`).
#
# ---
#
# ### Cleaned Dataset
#
# | BookID | Title | Status |
# | :--- | :--- | :--- |
# | 1 | Python | Available |
# | 2 | Java | Available |
# | 3 | C++ | Issued |
# | 4 | AI | Available |

# %% [markdown]
# Prompt 12 – Hotel Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    RoomNo,Guest,Days
    101,Raj,3
    102,Priya,
    103,Amit,Five
    101,Raj,3
    104,Neha,2

    Clean the dataset by removing duplicates, filling missing values, converting days into numeric format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the data cleaning report and the cleaned dataset.
#
# ### **Data Cleaning Summary:**
# 1. **Removed Duplicates:** Dropped the exact duplicate row for `101, Raj, 3`.
# 2. **Standardized Formats:** Converted text-based numbers ("Five") into standard numeric format (`5`).
# 3. **Handled Missing Values:** Imputed the missing `Days` value for Priya with `3` (the median/mode of the valid values).
#
# ---
#
# ### **Cleaned Dataset**
#
# | RoomNo | Guest | Days |
# | :--- | :--- | :--- |
# | 101 | Raj | 3 |
# | 102 | Priya | 3 |
# | 103 | Amit | 5 |
# | 104 | Neha | 2 |

# %% [markdown]
# Prompt 13 – Restaurant Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    OrderID,Customer,Bill
    1,Raj,500
    2,Priya,
    3,Amit,Seven Hundred
    1,Raj,500
    4,Neha,850

    Clean the dataset by removing duplicates, filling missing values, correcting bill amount, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### Data Cleaning Summary:
# 1. **Removed Duplicates:** Dropped the duplicate entry for `OrderID 1` (`1, Raj, 500`).
# 2. **Corrected Format:** Converted text value `"Seven Hundred"` in `OrderID 3` to its numeric equivalent `700`.
# 3. **Handled Missing Values:** Imputed the missing `Bill` amount for `OrderID 2` (Priya) using the median bill amount (`700`) of the dataset.
#
# ---
#
# ### Cleaned Dataset (Markdown Table):
#
# | OrderID | Customer | Bill |
# | :--- | :--- | :--- |
# | 1 | Raj | 500 |
# | 2 | Priya | 700 |
# | 3 | Amit | 700 |
# | 4 | Neha | 850 |

# %% [markdown]
# Prompt 14 – Vehicle Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    VehicleID,Owner,Year
    V1,Raj,2019
    V2,Priya,
    V3,Amit,Twenty Twenty
    V1,Raj,2019
    V4,Neha,2021

    Clean the dataset by removing duplicates, filling missing values, correcting year format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### Data Cleaning Summary:
# 1. **Deduplication:** Removed the duplicate row for `VehicleID: V1` (`V1,Raj,2019`).
# 2. **Format Standardisation:** Converted the text format `"Twenty Twenty"` in the `Year` column for `VehicleID: V3` to standard integer format `2020`.
# 3. **Missing Value Imputation:** Handled the missing `Year` value for `VehicleID: V2` by imputing it with `N/A` (or `Unknown`).
#
# ---
#
# ### Cleaned Dataset:
#
# | VehicleID | Owner | Year |
# | :--- | :--- | :--- |
# | V1 | Raj | 2019 |
# | V2 | Priya | N/A |
# | V3 | Amit | 2020 |
# | V4 | Neha | 2021 |

# %% [markdown]
# Prompt 15 – University Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    ID,Department,HOD
    1,CSE,Dr. Patel
    2,IT,
    3,ECE,Dr Shah
    1,CSE,Dr. Patel
    4,Mechanical,Dr. Mehta

    Clean the dataset by removing duplicates, filling missing values, standardizing HOD names, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ### **Data Cleaning Summary**
# 1. **Removed Duplicates:** Row 4 (`1,CSE,Dr. Patel`) was an exact duplicate of Row 1 and was removed.
# 2. **Standardized Text:** Added a period to `"Dr Shah"` (`Dr. Shah`) to maintain a consistent naming convention (`Dr. [Name]`).
# 3. **Handled Missing Values:** Filled the missing HOD value for the IT department with `"Unknown"` (or `"N/A"`).
#
# ---
#
# ### **Cleaned Dataset**
#
# | ID | Department | HOD |
# | :--- | :--- | :--- |
# | 1 | CSE | Dr. Patel |
# | 2 | IT | Unknown |
# | 3 | ECE | Dr. Shah |
# | 4 | Mechanical | Dr. Mehta |

# %% [markdown]
# Prompt 16 – Flight Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    FlightID,Destination,Seats
    F101,Delhi,120
    F102,,150
    F103,Mumbai,One Hundred
    F101,Delhi,120
    F104,Chennai,180

    Clean the dataset by removing duplicates, filling missing values, converting seats into numeric format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset presented as a Markdown table, followed by a brief summary of the cleaning steps performed.
#
# ### Cleaned Dataset
#
# | FlightID | Destination | Seats |
# | :--- | :--- | :--- |
# | F101 | Delhi | 120 |
# | F102 | Unknown | 150 |
# | F103 | Mumbai | 100 |
# | F104 | Chennai | 180 |
#
# ---
#
# ### Data Cleaning Log
#
# 1. **Deduplication**: Removed the duplicate row for `F101` (`F101,Delhi,120`).
# 2. **Missing Value Imputation**: Filled the missing `Destination` value for `F102` with `"Unknown"`.
# 3. **Data Type Standardisation**: Converted the text value `"One Hundred"` in the `Seats` column for `F103` into the numeric integer `100`.

# %% [markdown]
# Prompt 17 – Mobile Store Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    ID,Brand,Price
    1,Samsung,25000
    2,Apple,
    3,OnePlus,Twenty Thousand
    1,Samsung,25000
    4,Vivo,18000

    Clean the dataset by removing duplicates, filling missing values, correcting price format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ---
#
# ### **Data Cleaning Summary**
#
# 1. **Removed Duplicates:** Removed the duplicate entry for `ID: 1` (`1, Samsung, 25000`).
# 2. **Corrected Format:** Converted the text format `"Twenty Thousand"` for `ID: 3` into the numeric format `20000`.
# 3. **Imputed Missing Values:** Imputed the missing price for `ID: 2` (Apple) using the **median price** (`20000`) of the dataset to maintain numeric consistency.
#
# ---
#
# ### **Cleaned Dataset**
#
# | ID | Brand | Price |
# | :--- | :--- | :--- |
# | 1 | Samsung | 25000 |
# | 2 | Apple | 20000 |
# | 3 | OnePlus | 20000 |
# | 4 | Vivo | 18000 |

# %% [markdown]
# Prompt 18 – Online Orders Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    OrderID,Product,Quantity
    101,Laptop,2
    102,Mouse,
    103,Keyboard,Five
    101,Laptop,2
    104,Monitor,3

    Clean the dataset by removing duplicates, filling missing values, converting quantity into numeric format, and returning a Markdown table.
    """
)

print(response.text)

# %% [markdown]
# Prompt 19 – Electricity Billing Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    ConsumerID,Name,Units,Bill
    C101,Raj,250,1800
    C102,Priya,,1500
    C103,Amit,Three Hundred,2200
    C101,Raj,250,1800
    C104,Neha,180,

    Clean the dataset by removing duplicates, filling missing values, converting units into numeric format, correcting bill values, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset along with a summary of the data cleaning steps performed.
#
# ---
#
# ### **Data Cleaning Steps Performed**
#
# 1. **Deduplication**: Removed the duplicate record for `C101` (Raj).
# 2. **Text-to-Numeric Conversion**: Converted the string value `"Three Hundred"` for `C103` (Amit) to its numeric representation (`300`).
# 3. **Missing Value Imputation**:
#    * Derived the exact linear relationship between **Units** ($x$) and **Bill** ($y$) using existing complete pairs (`C101` and `C103`):
#      $$\text{Bill} = 8 \times \text{Units} - 200$$
#    * **Calculated Missing Units for `C102` (Priya)**:
#      $$\text{Units} = \frac{1500 + 200}{8} = 212.5$$
#    * **Calculated Missing Bill for `C104` (Neha)**:
#      $$\text{Bill} = 8 \times 180 - 200 = 1240$$
#
# ---
#
# ### **Cleaned Dataset**
#
# | ConsumerID | Name | Units | Bill |
# | :--- | :--- | :--- | :--- |
# | C101 | Raj | 250 | 1800 |
# | C102 | Priya | 212.5 | 1500 |
# | C103 | Amit | 300 | 2200 |
# ...

# %% [markdown]
# Prompt 20 – Payroll Dataset

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",   # Replace with a model available to your account
    contents="""
    You are a Data Cleaning Expert.

    Dataset:

    EmpID,Employee,Experience,Salary
    E101,Amit,5,55000
    E102,Priya,,62000
    E103,Rahul,Three,58000
    E101,Amit,5,55000
    E104,Neha,8,

    Clean the dataset by removing duplicates, filling missing values, converting experience into numeric format, and returning a Markdown table.
    """
)

print(response.text)
# Out:
# Here is the cleaned dataset formatted as a Markdown table.
#
# ### Data Cleaning Summary
# 1. **Deduplication:** Removed the duplicate entry for `E101` (Amit).
# 2. **Type Conversion:** Converted the string value `"Three"` for `E103` (Rahul) into the numeric value `3`.
# 3. **Missing Value Imputation:**
#    * **Experience (`E102` - Priya):** Imputed missing value with the **median experience** of the dataset (**5 years**).
#    * **Salary (`E104` - Neha):** Imputed missing value with the **median salary** of the dataset (**58,000**).
#
# ---
#
# ### Cleaned Dataset
#
# | EmpID | Employee | Experience | Salary |
# | :--- | :--- | :--- | :--- |
# | E101 | Amit | 5 | 55000 |
# | E102 | Priya | 5 | 62000 |
# | E103 | Rahul | 3 | 58000 |
# | E104 | Neha | 8 | 58000 |
